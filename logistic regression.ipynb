# %%
import numpy as np
import pandas as pd

# %%
matches = pd.read_csv("matches.csv")
delivery = pd.read_csv("deliveries.csv")
matches
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
final_df= pd.read_csv("modified_dataset.csv")

final_df.dropna(inplace=True)
final_df=final_df[final_df['balls_left']!=0]
final_df
# Out:
#                       batting_team         bowling_team       city  \
# 0      Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 1      Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 2      Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 3      Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 4      Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# ...                            ...                  ...        ...
# 72407          Chennai Super Kings       Mumbai Indians  Hyderabad
# 72408          Chennai Super Kings       Mumbai Indians  Hyderabad
# 72409          Chennai Super Kings       Mumbai Indians  Hyderabad
# 72410          Chennai Super Kings       Mumbai Indians  Hyderabad
# 72411          Chennai Super Kings       Mumbai Indians  Hyderabad
#
#        total_runs_x  balls_left  required_runs  wickets_left       crr  \
# 0               208         119            207            10  6.000000
# ...

# %%
X = final_df.iloc[:,:-1]
y= final_df.iloc[:,-1]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#                       batting_team                 bowling_team  \
# 10798             Rajasthan Royals              Kings XI Punjab
# 72337          Chennai Super Kings               Mumbai Indians
# 2142                Mumbai Indians  Royal Challengers Bangalore
# 43506        Kolkata Knight Riders              Kings XI Punjab
# 65614        Kolkata Knight Riders          Sunrisers Hyderabad
# ...                            ...                          ...
# 50094             Rajasthan Royals          Sunrisers Hyderabad
# 20679              Deccan Chargers  Royal Challengers Bangalore
# 21511             Delhi Daredevils               Mumbai Indians
# 51055  Royal Challengers Bangalore          Chennai Super Kings
# 5208   Royal Challengers Bangalore             Delhi Daredevils
#
#                 city  total_runs_x  balls_left  required_runs  wickets_left  \
# 10798      Cape Town           140         110            132             9
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder,StandardScaler

trf = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(sparse_output=False, drop='first'), ['batting_team', 'bowling_team', 'city']),
        ('num', StandardScaler(), ['total_runs_x', 'balls_left','required_runs','wickets_left','crr','rrr'])  
    ],
    remainder='passthrough'
)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city']),
#                                                  ('num', StandardScaler(),
#                                                   ['total_runs_x', 'balls_left',
#                                                    'required_runs',
#                                                    'wickets_left', 'crr',
#                                                    'rrr'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
y_pred = pipe.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8064335272268555

# %%
teams = final_df['batting_team'].unique()
teams
# Out:
# array(['Royal Challengers Bangalore', 'Delhi Daredevils',
#        'Mumbai Indians', 'Kings XI Punjab', 'Kolkata Knight Riders',
#        'Sunrisers Hyderabad', 'Rajasthan Royals', 'Chennai Super Kings',
#        'Deccan Chargers', 'Delhi Capitals'], dtype=object)

# %%
final_df['city'].unique()
# Out:
# array(['Hyderabad', 'Bangalore', 'Mumbai', 'Indore', 'Kolkata', 'Delhi',
#        'Chandigarh', 'Jaipur', 'Chennai', 'Cape Town', 'Port Elizabeth',
#        'Durban', 'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi', 'Abu Dhabi',
#        'Sharjah', 'Mohali', 'Bengaluru'], dtype=object)

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl(5)','wb'))

# %%
final_df['batting_team'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Delhi Daredevils',
#        'Mumbai Indians', 'Kings XI Punjab', 'Kolkata Knight Riders',
#        'Sunrisers Hyderabad', 'Rajasthan Royals', 'Chennai Super Kings',
#        'Deccan Chargers', 'Delhi Capitals'], dtype=object)

# %%
# Access the Logistic Regression model
model = pipe.named_steps['step2']

# Now you can use the model's attributes, such as coef_ and intercept_
print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)
# Out:
# Coefficients: [[-2.11170115  0.06379035 -1.49058643 -1.0210641  -0.85787538 -0.71869155
#   -0.80715531 -1.2123875  -1.15415645  0.31705557 -1.21839628  0.31246043
#   -0.30391184 -0.24338636 -0.87262134 -0.48773644  0.11883427 -0.23464435
#    0.05728579  1.02413208  0.99113983 -0.26556298 -1.94689048  0.92188432
#    0.49513419 -0.66930801 -0.09014864  0.28562054  1.18587426 -0.53744307
#   -0.11783849  0.6207624   2.95412544  1.30652051  0.30112524  0.98516527
#    0.88872172  0.41046003  0.72342127 -0.41285894  1.39633844  0.96223141
#    1.24998077  1.07435335  0.81203214  0.62135725  0.00682401  1.57256626
#   -2.88634658  1.35352131  0.06479192 -0.44390449]]
# Intercept: [0.71332207]

# %%
feature_names = pipe.named_steps['step1'].get_feature_names_out()

# %%
import pandas as pd

coefficients = model.coef_[0]
importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': coefficients
})

# Add absolute importance for better ranking
importance_df['Absolute Importance'] = importance_df['Importance'].abs()

# Sort by absolute importance
importance_df = importance_df.sort_values(by='Absolute Importance', ascending=False)

print(importance_df)
# Out:
#                                           Feature  Importance  \
# 32                               cat__city_Indore    2.954125
# 48                             num__required_runs   -2.886347
# 0               cat__batting_team_Deccan Chargers   -2.111701
# 22                            cat__city_Cape Town   -1.946890
# 47                                num__balls_left    1.572566
# 2              cat__batting_team_Delhi Daredevils   -1.490586
# 40                       cat__city_Port Elizabeth    1.396338
# 49                              num__wickets_left    1.353521
# 33                               cat__city_Jaipur    1.306521
# 42                               cat__city_Raipur    1.249981
# 10               cat__bowling_team_Delhi Capitals   -1.218396
# 7   cat__batting_team_Royal Challengers Bangalore   -1.212388
# 28                           cat__city_Dharamsala    1.185874
# 8           cat__batting_team_Sunrisers Hyderabad   -1.154156
# ...

# %%
import pandas as pd

# Combine feature names with coefficients
importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Coefficient': coefficients
})

# Filter for features related to team and city
relevant_features = importance_df[importance_df['Feature'].str.contains('batting_team|bowling_team|city')]

# Sort by absolute coefficient value
relevant_features['Absolute Coefficient'] = relevant_features['Coefficient'].abs()
relevant_features = relevant_features.sort_values(by='Absolute Coefficient', ascending=False)

print(relevant_features)
# Out:
#                                           Feature  Coefficient  \
# 32                               cat__city_Indore     2.954125
# 0               cat__batting_team_Deccan Chargers    -2.111701
# 22                            cat__city_Cape Town    -1.946890
# 2              cat__batting_team_Delhi Daredevils    -1.490586
# 40                       cat__city_Port Elizabeth     1.396338
# 33                               cat__city_Jaipur     1.306521
# 42                               cat__city_Raipur     1.249981
# 10               cat__bowling_team_Delhi Capitals    -1.218396
# 7   cat__batting_team_Royal Challengers Bangalore    -1.212388
# 28                           cat__city_Dharamsala     1.185874
# 8           cat__batting_team_Sunrisers Hyderabad    -1.154156
# 43                               cat__city_Ranchi     1.074353
# 19                            cat__city_Bangalore     1.024132
# 3               cat__batting_team_Kings XI Punjab    -1.021064
# ...
